# %%
import cv2
import os.path
import tensorflow as tf
import helper
import tests as tests
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
import random
import re

# %%
image = mpimg.imread('../lyft_data/Train/CameraRGB/198.png')
plt.imshow(image)

# %%
image_resized= cv2.resize(image,(700, 500))
plt.imshow(image_resized)
